# %%
import plotly.figure_factory as ff
import pandas as pd

from plotly.offline import iplot

scope=['Massachusetts']
df=pd.read_csv('us population.csv')
df_new=df[df['STNAME'].isin(scope)]
values=df_new['TOT_POP'].tolist()
fips=df_new['FIPS'].tolist()

#you can also not give colorscale & still get result but in same color in different shades
colorscale = ["#2daa4b", "#80b1d3", "#fdb462", "#b3de69", "#fccde5", "#ff0000", "#cce6f4",
              "#80b1d3", "#fdb462", "#b3de69", "#fccde5", "#9ba991", "#604d74", "#afcbc7",
              "#80b1d3", "#fdb462", "#b3de69", "#fccde5", "#f0c800", "#387e75", "#fce7e7",
              "#8dd3c7", "#ffffb3", "#bebada", "#fb8072", "#00778b", "#1d2d43", "#460606",
              "#8dd3c7", "#ffffb3", "#bebada", "#fb8072", "#af3205", "#436e6f", "#f6a2a2",
              "#d9d9d9", "#bc80bd", "#ccebc5", "#ffed6f", "#5a3791", "#1d2d43", "#0068a0",
              "#d9d9d9", "#bc80bd", "#ccebc5", "#ffed6f", "#f6c4d2", "#675974", "#bb1212",
              "#d9d9d9", "#bc80bd", "#ccebc5", "#ffed6f", "#ffd03e", "#4f5573", "#327169",
              "#3697dd", "#8dd3c7", "#ffffb3", "#bebada", "#fb8072", "#ea1717", "#66b4de",]

fig=ff.create_choropleth(
    fips=fips,
    values=values,
    scope=scope,
    colorscale=colorscale,
    round_legend_values=True,
    simplify_county=0,
    simplify_state=0,
    county_outline={'color':'rgb(15,15,55)','width':0.5},
    state_outline={'width':0.5},
    legend_title='Population per County',
    title='Massachusetts'
    )

iplot(fig)
# Out:
# <div>                            <div id="f7b2982a-3311-49ef-956f-e4d7af7704da" class="plotly-graph-div" style="height:450px; width:900px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f7b2982a-3311-49ef-956f-e4d7af7704da")) {                    Plotly.newPlot(                        "f7b2982a-3311-49ef-956f-e4d7af7704da",                        [{"fill": "toself", "fillcolor": "#2daa4b", "hoverinfo": "none", "line": {"color": "rgb(15,15,55)", "width": 0.5}, "mode": "lines", "name": "10298", "type": "scatter", "x": [-70.234054, -70.2236082504102, -70.22121899999999, -70.2208006403107, -70.21942831067169, -70.21504, -70.21171199999999, -70.2116092230359, -70.2105269365785, -70.2061254145417, -70.20173, -70.20052309882789, -70.1968995866617, -70.19388599999999, -70.1918870027769, -70.19174699999999, -70.1923053296939, -70.195788, -70.195843738205, -70.20220499999999, -70.2042555039129, -70.2054887709883, -70.20743399999999, -70.205692, -70.2025846250867, -70.19911499999999, -70.1949980459443, -70.193411, -70.18699099999999, -70.1855105039345, -70.1727984311467, -70.16772987052009, -70.1630617648737, -70.1319283496631, -70.12446, -70.1228553487567, -70.109613, -70.104415, -70.104110790002, -70.09468675363749, -70.09252138551778, -70.092142, -70.082072, -70.07563584478339, -70.06